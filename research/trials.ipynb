# %%
import gdown

url = 'https://drive.google.com/file/d/1_OU_E76YpZQGGZpLhQmT8qoqksDNn14p/view?usp=drive_link'

unique_id = '1_OU_E76YpZQGGZpLhQmT8qoqksDNn14p'


prefix_url = 'https://drive.google.com/uc?/export=download&id='

gdown.download(prefix_url+unique_id, 'House-rental-Dataset.zip')
# Out:
# Downloading...
# From: https://drive.google.com/uc?/export=download&id=1_OU_E76YpZQGGZpLhQmT8qoqksDNn14p
# To: c:\house-rent-prediction-model\research\House-rental-Dataset.zip
# 100%|██████████| 170k/170k [00:00<00:00, 1.39MB/s]
# 'House-rental-Dataset.zip'
